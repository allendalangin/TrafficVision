# %%
import mindspore as ms
import numpy as np
from mindspore import Tensor

def check_mindspore_gpu():
    """
    Checks if MindSpore can successfully initialize and use the GPU.
    """
    print(f"MindSpore version: {ms.__version__}")
    try:
        # 1. Attempt to set the backend device to 'GPU'.
        #    If this fails, it will raise an exception.
        ms.context.set_context(device_target="GPU")
        print("✅ Successfully set device_target to 'GPU'.")

        # 2. Perform a simple operation to verify the backend is functional.
        x = Tensor(np.ones([2, 2]), ms.float32)
        y = Tensor(np.ones([2, 2]), ms.float32)
        result = x + y

        print("✅ A simple tensor addition was executed successfully.")
        print("\n🎉 MindSpore is configured correctly and can use your GPU!")

    except RuntimeError as e:
        print("\n❌ MindSpore could not initialize the GPU backend.")
        print(f"   Error details: {e}")
        print("\n   Please check the following:")
        print("   1. Your NVIDIA drivers are installed correctly.")
        print("   2. The installed MindSpore version matches your CUDA version.")
        print("   3. You installed the 'mindspore-gpu' package.")

    except Exception as e:
        print(f"\n❌ An unexpected error occurred: {e}")


if __name__ == "__main__":
    check_mindspore_gpu()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import mindspore as ms
#       2 import numpy as np
#       3 from mindspore import Tensor
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\__init__.py:19
#      16 from __future__ import absolute_import
#      18 from mindspore.run_check import run_check
# ---> 19 from mindspore import common, dataset, mindrecord, train, log, amp
#      20 from mindspore import profiler, communication, numpy, parallel, hal, runtime, device_context
#      21 from mindspore.common import *
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\common\__init__.py:35
#      33 from mindspore.common.lazy_inline import lazy_inline
#      34 from mindspore.common.no_inline import no_inline
# ---> 35 from mindspore.common.mindir_util import load_mindir, save_mindir
#      36 from mindspore.common.symbol import Symbol
#      37 from mindspore.common.recompute import recompute
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\common\mindir_util.py:22
#      20 from mindspore import log as logger
#      21 from mindspore import _checkparam as Validator
# ---> 22 from mindspore.train.mind_ir_pb2 import ModelProto as mindir_model
#      25 def load_mindir(file_name):
#      26     """
#      27     load protobuf file.
#      28
#    (...)     46         >>> md = ms.load_mindir("test.mindir")
#      47     """
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\train\__init__.py:22
#      15 """
#      16 High-Level training interfaces.
#      17
#      18 Helper functions in train pipelines.
#      19 """
#      20 from __future__ import absolute_import
# ---> 22 from mindspore.train.model import Model
#      23 from mindspore.train.dataset_helper import DatasetHelper, connect_network_with_dataset
#      24 from mindspore.train import amp
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\train\model.py:31
#      29 import mindspore
#      30 from mindspore import log as logger
# ---> 31 from mindspore.train.serialization import save_checkpoint, load_checkpoint
#      32 from mindspore.train.callback._checkpoint import ModelCheckpoint, _chg_ckpt_file_name_if_same_exist
#      33 from mindspore.common.tensor import Tensor
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\train\serialization.py:44
#      41 from safetensors.numpy import save_file, load_file
#      42 from safetensors import safe_open
# ---> 44 from mindspore.train.checkpoint_pb2 import Checkpoint
#      45 from mindspore.train.mind_ir_pb2 import ModelProto as mindir_model
#      46 from mindspore.train.print_pb2 import Print
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\train\checkpoint_pb2.py:36
#      11 _sym_db = _symbol_database.Default()
#      16 DESCRIPTOR = _descriptor.FileDescriptor(
#      17   name='checkpoint.proto',
#      18   package='',
#    (...)     22   serialized_pb=b'\n\x10\x63heckpoint.proto\"\x93\x01\n\nCheckpoint\x12 \n\x05value\x18\x01 \x03(\x0b\x32\x11.Checkpoint.Value\x1a\x63\n\x05Value\x12\x0b\n\x03tag\x18\x01 \x02(\t\x12\x1e\n\x06tensor\x18\x02 \x01(\x0b\x32\x0c.TensorProtoH\x00\x12$\n\tmaptensor\x18\x03 \x01(\x0b\x32\x0f.MapTensorProtoH\x00\x42\x07\n\x05value\"H\n\x0bTensorProto\x12\x0c\n\x04\x64ims\x18\x01 \x03(\x03\x12\x13\n\x0btensor_type\x18\x02 \x02(\t\x12\x16\n\x0etensor_content\x18\x03 \x02(\x0c\".\n\x0eMapTensorProto\x12\x1c\n\x06tensor\x18\x01 \x03(\x0b\x32\x0c.TensorProto'
#      23 )
#      28 _CHECKPOINT_VALUE = _descriptor.Descriptor(
#      29   name='Value',
#      30   full_name='Checkpoint.Value',
#      31   filename=None,
#      32   file=DESCRIPTOR,
#      33   containing_type=None,
#      34   create_key=_descriptor._internal_create_key,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='tag', full_name='Checkpoint.Value.tag', index=0,
#      38       number=1, type=9, cpp_type=9, label=2,
#      39       has_default_value=False, default_value=b"".decode('utf-8'),
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR,  create_key=_descriptor._internal_create_key),
#      43     _descriptor.FieldDescriptor(
#      44       name='tensor', full_name='Checkpoint.Value.tensor', index=1,
#      45       number=2, type=11, cpp_type=10, label=1,
#      46       has_default_value=False, default_value=None,
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR,  create_key=_descriptor._internal_create_key),
#      50     _descriptor.FieldDescriptor(
#      51       name='maptensor', full_name='Checkpoint.Value.maptensor', index=2,
#      52       number=3, type=11, cpp_type=10, label=1,
#      53       has_default_value=False, default_value=None,
#      54       message_type=None, enum_type=None, containing_type=None,
#      55       is_extension=False, extension_scope=None,
#      56       serialized_options=None, file=DESCRIPTOR,  create_key=_descriptor._internal_create_key),
#      57   ],
#      58   extensions=[
#      59   ],
#      60   nested_types=[],
#      61   enum_types=[
#      62   ],
#      63   serialized_options=None,
#      64   is_extendable=False,
#      65   syntax='proto2',
#      66   extension_ranges=[],
#      67   oneofs=[
#      68     _descriptor.OneofDescriptor(
#      69       name='value', full_name='Checkpoint.Value.value',
#      70       index=0, containing_type=None,
#      71       create_key=_descriptor._internal_create_key,
#      72     fields=[]),
#      73   ],
#      74   serialized_start=69,
#      75   serialized_end=168,
#      76 )
#      78 _CHECKPOINT = _descriptor.Descriptor(
#      79   name='Checkpoint',
#      80   full_name='Checkpoint',
#    (...)    106   serialized_end=168,
#     107 )
#     110 _TENSORPROTO = _descriptor.Descriptor(
#     111   name='TensorProto',
#     112   full_name='TensorProto',
#    (...)    152   serialized_end=242,
#     153 )
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\google\protobuf\descriptor.py:553, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     547 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     548             default_value, message_type, enum_type, containing_type,
#     549             is_extension, extension_scope, options=None,
#     550             serialized_options=None,
#     551             has_default_value=True, containing_oneof=None, json_name=None,
#     552             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 553   _message.Message._CheckCalledFromGeneratedFile()
#     554   if is_extension:
#     555     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
import mindspore as ms
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import mindspore as ms
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\__init__.py:19
#      16 from __future__ import absolute_import
#      18 from mindspore.run_check import run_check
# ---> 19 from mindspore import common, dataset, mindrecord, train, log, amp
#      20 from mindspore import profiler, communication, numpy, parallel, hal, runtime, device_context
#      21 from mindspore.common import *
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\common\__init__.py:35
#      33 from mindspore.common.lazy_inline import lazy_inline
#      34 from mindspore.common.no_inline import no_inline
# ---> 35 from mindspore.common.mindir_util import load_mindir, save_mindir
#      36 from mindspore.common.symbol import Symbol
#      37 from mindspore.common.recompute import recompute
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\common\mindir_util.py:22
#      20 from mindspore import log as logger
#      21 from mindspore import _checkparam as Validator
# ---> 22 from mindspore.train.mind_ir_pb2 import ModelProto as mindir_model
#      25 def load_mindir(file_name):
#      26     """
#      27     load protobuf file.
#      28
#    (...)     46         >>> md = ms.load_mindir("test.mindir")
#      47     """
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\train\__init__.py:22
#      15 """
#      16 High-Level training interfaces.
#      17
#      18 Helper functions in train pipelines.
#      19 """
#      20 from __future__ import absolute_import
# ---> 22 from mindspore.train.model import Model
#      23 from mindspore.train.dataset_helper import DatasetHelper, connect_network_with_dataset
#      24 from mindspore.train import amp
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\train\model.py:31
#      29 import mindspore
#      30 from mindspore import log as logger
# ---> 31 from mindspore.train.serialization import save_checkpoint, load_checkpoint
#      32 from mindspore.train.callback._checkpoint import ModelCheckpoint, _chg_ckpt_file_name_if_same_exist
#      33 from mindspore.common.tensor import Tensor
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\train\serialization.py:44
#      41 from safetensors.numpy import save_file, load_file
#      42 from safetensors import safe_open
# ---> 44 from mindspore.train.checkpoint_pb2 import Checkpoint
#      45 from mindspore.train.mind_ir_pb2 import ModelProto as mindir_model
#      46 from mindspore.train.print_pb2 import Print
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\mindspore\train\checkpoint_pb2.py:36
#      11 _sym_db = _symbol_database.Default()
#      16 DESCRIPTOR = _descriptor.FileDescriptor(
#      17   name='checkpoint.proto',
#      18   package='',
#    (...)     22   serialized_pb=b'\n\x10\x63heckpoint.proto\"\x93\x01\n\nCheckpoint\x12 \n\x05value\x18\x01 \x03(\x0b\x32\x11.Checkpoint.Value\x1a\x63\n\x05Value\x12\x0b\n\x03tag\x18\x01 \x02(\t\x12\x1e\n\x06tensor\x18\x02 \x01(\x0b\x32\x0c.TensorProtoH\x00\x12$\n\tmaptensor\x18\x03 \x01(\x0b\x32\x0f.MapTensorProtoH\x00\x42\x07\n\x05value\"H\n\x0bTensorProto\x12\x0c\n\x04\x64ims\x18\x01 \x03(\x03\x12\x13\n\x0btensor_type\x18\x02 \x02(\t\x12\x16\n\x0etensor_content\x18\x03 \x02(\x0c\".\n\x0eMapTensorProto\x12\x1c\n\x06tensor\x18\x01 \x03(\x0b\x32\x0c.TensorProto'
#      23 )
#      28 _CHECKPOINT_VALUE = _descriptor.Descriptor(
#      29   name='Value',
#      30   full_name='Checkpoint.Value',
#      31   filename=None,
#      32   file=DESCRIPTOR,
#      33   containing_type=None,
#      34   create_key=_descriptor._internal_create_key,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='tag', full_name='Checkpoint.Value.tag', index=0,
#      38       number=1, type=9, cpp_type=9, label=2,
#      39       has_default_value=False, default_value=b"".decode('utf-8'),
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR,  create_key=_descriptor._internal_create_key),
#      43     _descriptor.FieldDescriptor(
#      44       name='tensor', full_name='Checkpoint.Value.tensor', index=1,
#      45       number=2, type=11, cpp_type=10, label=1,
#      46       has_default_value=False, default_value=None,
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR,  create_key=_descriptor._internal_create_key),
#      50     _descriptor.FieldDescriptor(
#      51       name='maptensor', full_name='Checkpoint.Value.maptensor', index=2,
#      52       number=3, type=11, cpp_type=10, label=1,
#      53       has_default_value=False, default_value=None,
#      54       message_type=None, enum_type=None, containing_type=None,
#      55       is_extension=False, extension_scope=None,
#      56       serialized_options=None, file=DESCRIPTOR,  create_key=_descriptor._internal_create_key),
#      57   ],
#      58   extensions=[
#      59   ],
#      60   nested_types=[],
#      61   enum_types=[
#      62   ],
#      63   serialized_options=None,
#      64   is_extendable=False,
#      65   syntax='proto2',
#      66   extension_ranges=[],
#      67   oneofs=[
#      68     _descriptor.OneofDescriptor(
#      69       name='value', full_name='Checkpoint.Value.value',
#      70       index=0, containing_type=None,
#      71       create_key=_descriptor._internal_create_key,
#      72     fields=[]),
#      73   ],
#      74   serialized_start=69,
#      75   serialized_end=168,
#      76 )
#      78 _CHECKPOINT = _descriptor.Descriptor(
#      79   name='Checkpoint',
#      80   full_name='Checkpoint',
#    (...)    106   serialized_end=168,
#     107 )
#     110 _TENSORPROTO = _descriptor.Descriptor(
#     111   name='TensorProto',
#     112   full_name='TensorProto',
#    (...)    152   serialized_end=242,
#     153 )
#
# File f:\Codes\TrafficVisionProject\venv\Lib\site-packages\google\protobuf\descriptor.py:553, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     547 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     548             default_value, message_type, enum_type, containing_type,
#     549             is_extension, extension_scope, options=None,
#     550             serialized_options=None,
#     551             has_default_value=True, containing_oneof=None, json_name=None,
#     552             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 553   _message.Message._CheckCalledFromGeneratedFile()
#     554   if is_extension:
#     555     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
